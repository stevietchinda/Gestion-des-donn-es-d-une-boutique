# %%
import pandas as pd # Pour manipuler les DataFrames.

# %%
# !pip install xlrd

# %%
# Lire le DataFrame
data_web =pd.read_csv('web.csv')

# %%
# Afficher les premières lignes du DataFrame
data_web.head(5)
# Out:
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
# 3                15300        0             0             0             0.0
# 4                19814        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author            post_date  ...  \
# 0         10.0    taxable        NaN          1.0  2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0  2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0  2018-02-08 13:49:41  ...
# 3          0.0    taxable        NaN          2.0  2018-02-08 14:08:36  ...
# 4          3.0    taxable        NaN          2.0  2018-02-09 14:01:05  ...
#
# ...

# %%
# Afficher toutes les colonnes du DataFrame
for raw in data_web:
   print(raw)
# Out:
# sku
# virtual
# downloadable
# rating_count
# average_rating
# total_sales
# tax_status
# tax_class
# post_author
# post_date
# post_date_gmt
# post_content
# post_title
# post_excerpt
# post_status
# comment_status
# ping_status
# post_password
# post_name
# post_modified
# post_modified_gmt
# post_content_filtered
# post_parent
# guid
# menu_order
# post_type
# post_mime_type
# comment_count

# %%
#afficher toutes les informations sur le DataFrame
data_web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    1428 non-null   object
#  1   virtual                1513 non-null   int64
#  2   downloadable           1513 non-null   int64
#  3   rating_count           1513 non-null   int64
#  4   average_rating         1430 non-null   float64
#  5   total_sales            1430 non-null   float64
#  6   tax_status             716 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            1430 non-null   float64
#  9   post_date              1430 non-null   object
#  10  post_date_gmt          1430 non-null   object
#  11  post_content           0 non-null      float64
#  12  post_title             1430 non-null   object
#  13  post_excerpt           716 non-null    object
# ...

# %%
# Renommer la colonne sku

data_web = data_web.rename(columns={'sku' : 'id_web' })

# %%
data_web.head(3)
# Out:
#                 id_web  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author            post_date  ...  \
# 0         10.0    taxable        NaN          1.0  2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0  2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0  2018-02-08 13:49:41  ...
#
#                                      post_name        post_modified  \
# 0                       bon-cadeau-de-25-euros  2018-06-01 14:13:57
# 1  pierre-jean-villa-saint-joseph-preface-2018  2019-12-30 09:30:29
# 2    pierre-jean-villa-saint-joseph-tilde-2017  2019-12-21 09:00:17
#
#      post_modified_gmt post_content_filtered post_parent  \
# ...

# %%
data_web.info(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_web                 1428 non-null   object
#  1   virtual                1513 non-null   int64
#  2   downloadable           1513 non-null   int64
#  3   rating_count           1513 non-null   int64
#  4   average_rating         1430 non-null   float64
#  5   total_sales            1430 non-null   float64
#  6   tax_status             716 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            1430 non-null   float64
#  9   post_date              1430 non-null   object
#  10  post_date_gmt          1430 non-null   object
#  11  post_content           0 non-null      float64
#  12  post_title             1430 non-null   object
#  13  post_excerpt           716 non-null    object
# ...

# %%
# Crée un DataFrame booléen indiquant la présence de valeurs nulles.
# Calcule le nombre de valeurs nulles dans chaque colonne.
# Affiche ce nombre pour chaque colonne du DataFrame.
print(data_web.isnull().sum())
# Out:
# id_web                     85
# virtual                     0
# downloadable                0
# rating_count                0
# average_rating             83
# total_sales                83
# tax_status                797
# tax_class                1513
# post_author                83
# post_date                  83
# post_date_gmt              83
# post_content             1513
# post_title                 83
# post_excerpt              797
# post_status                83
# comment_status             83
# ping_status                83
# post_password            1513
# post_name                  83
# post_modified              83
# post_modified_gmt          83
# post_content_filtered    1513
# post_parent                83
# guid                       83
# menu_order                 83
# post_type                  83
# post_mime_type            799
# comment_count              83
# dtype: int64

# %%
#  Remplacement des 0 du dataFrame par NaN

import numpy as np  # Pour utiliser np.nan qui représente les valeurs manquantes.
data_web=data_web.replace(0,np.nan)
print(len(data_web.index), 'lignes avant la suppression des NaN') # Renvoie le nombre de lignes dans le DataFrame data_web.
data_web.head()
# Out:
# 1513 lignes avant la suppression des NaN
#                 id_web  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros      NaN           NaN           NaN             NaN
# 1                15298      NaN           NaN           NaN             NaN
# 2                15296      NaN           NaN           NaN             NaN
# 3                15300      NaN           NaN           NaN             NaN
# 4                19814      NaN           NaN           NaN             NaN
#
#    total_sales tax_status  tax_class  post_author            post_date  ...  \
# 0         10.0    taxable        NaN          1.0  2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0  2018-02-08 12:58:52  ...
# 2          NaN    taxable        NaN          2.0  2018-02-08 13:49:41  ...
# 3          NaN    taxable        NaN          2.0  2018-02-08 14:08:36  ...
# 4          3.0    taxable        NaN          2.0  2018-02-09 14:01:05  ...
#
# ...

# %%
#Suppression des lignes NaN

data_web =data_web.dropna(how= 'all') 
print(len(data_web.index), 'lignes après la suppression des NaN') # Renvoie le nombre de lignes dans le DataFrame data_web.
data_web.head()
# Out:
# 1430 lignes après la suppression des NaN
#                 id_web  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros      NaN           NaN           NaN             NaN
# 1                15298      NaN           NaN           NaN             NaN
# 2                15296      NaN           NaN           NaN             NaN
# 3                15300      NaN           NaN           NaN             NaN
# 4                19814      NaN           NaN           NaN             NaN
#
#    total_sales tax_status  tax_class  post_author            post_date  ...  \
# 0         10.0    taxable        NaN          1.0  2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0  2018-02-08 12:58:52  ...
# 2          NaN    taxable        NaN          2.0  2018-02-08 13:49:41  ...
# 3          NaN    taxable        NaN          2.0  2018-02-08 14:08:36  ...
# 4          3.0    taxable        NaN          2.0  2018-02-09 14:01:05  ...
#
# ...

# %%
# Conversion de la list en DF

print(type(data_web)) # pour verifier le type de donnée
data_web_df = pd.DataFrame(data_web)  
print(type(data_web_df))
data_web_df.head()
#data_web_null = data_web[data_web['id_web'].isnull()]

#print(data_web_null)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#                 id_web  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros      NaN           NaN           NaN             NaN
# 1                15298      NaN           NaN           NaN             NaN
# 2                15296      NaN           NaN           NaN             NaN
# 3                15300      NaN           NaN           NaN             NaN
# 4                19814      NaN           NaN           NaN             NaN
#
#    total_sales tax_status  tax_class  post_author            post_date  ...  \
# 0         10.0    taxable        NaN          1.0  2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0  2018-02-08 12:58:52  ...
# 2          NaN    taxable        NaN          2.0  2018-02-08 13:49:41  ...
# 3          NaN    taxable        NaN          2.0  2018-02-08 14:08:36  ...
# ...

# %%
# Recherche des ‘id_web’ nulles (NaN)
#data_web_df = pd.DataFrame(data_web, columns=['id_web'])

data_web_null = data_web_df[data_web_df['id_web'].isnull()]
data_web_null.head()
# Out:
#     id_web  virtual  downloadable  rating_count  average_rating  total_sales  \
# 470    NaN      NaN           NaN           NaN             NaN          NaN
# 471    NaN      NaN           NaN           NaN             NaN          NaN
#
#     tax_status  tax_class  post_author            post_date  ...  \
# 470    taxable        NaN          2.0  2018-07-31 12:07:23  ...
# 471    taxable        NaN          2.0  2018-08-08 11:23:43  ...
#
#                                       post_name        post_modified  \
# 470  pierre-jean-villa-cote-rotie-fongeant-2017  2019-11-02 13:24:15
# 471    pierre-jean-villa-condrieu-suspendu-2018  2019-11-02 13:24:01
#
#        post_modified_gmt post_content_filtered post_parent  \
# 470  2019-11-02 12:24:15                   NaN         NaN
# 471  2019-11-02 12:24:01                   NaN         NaN
#
#                                                   guid menu_order  post_type  \
# ...

# %%
# Suppression des produits ayant pour ‘id_web’ nulles (NaN)

data_web = data_web.dropna(subset=['id_web'])

# %%
print(len(data_web.index), 'lignes après la suppression des NaN') # Renvoie le nombre de lignes dans le DataFrame data_web.
data_web.head()
# Out:
# 1428 lignes après la suppression des NaN
#                 id_web  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros      NaN           NaN           NaN             NaN
# 1                15298      NaN           NaN           NaN             NaN
# 2                15296      NaN           NaN           NaN             NaN
# 3                15300      NaN           NaN           NaN             NaN
# 4                19814      NaN           NaN           NaN             NaN
#
#    total_sales tax_status  tax_class  post_author            post_date  ...  \
# 0         10.0    taxable        NaN          1.0  2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0  2018-02-08 12:58:52  ...
# 2          NaN    taxable        NaN          2.0  2018-02-08 13:49:41  ...
# 3          NaN    taxable        NaN          2.0  2018-02-08 14:08:36  ...
# 4          3.0    taxable        NaN          2.0  2018-02-09 14:01:05  ...
#
# ...

# %%
#Selection des données importantes

data_web = data_web[['id_web', 'total_sales', 'post_date', 'post_title', 'post_excerpt', 'post_name', 'post_type']]
data_web
# Out:
#                    id_web  total_sales            post_date  \
# 0     bon-cadeau-25-euros         10.0  2018-06-01 13:53:46
# 1                   15298          6.0  2018-02-08 12:58:52
# 2                   15296          NaN  2018-02-08 13:49:41
# 3                   15300          NaN  2018-02-08 14:08:36
# 4                   19814          3.0  2018-02-09 14:01:05
# ...                   ...          ...                  ...
# 1508                16135          5.0  2020-04-25 13:22:38
# 1509                15891          NaN  2020-05-02 14:53:40
# 1510                15887          NaN  2020-05-02 15:00:54
# 1511              13127-1          NaN  2020-06-09 15:42:04
# 1512                16230          NaN  2020-07-20 11:00:00
#
#                                              post_title  \
# 0                                     Bon cadeau de 25€
# 1           Pierre Jean Villa Saint-Joseph Préface 2018
# 2       Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# ...

# %%
#permet d'isoler et d'afficher toutes les lignes du DataFrame data_web où la colonne 'id_web' contient des valeurs dupliquées.

data_web.loc[data_web['id_web'].duplicated(keep=False),:]
# Out:
#                    id_web  total_sales            post_date  \
# 0     bon-cadeau-25-euros         10.0  2018-06-01 13:53:46
# 1                   15298          6.0  2018-02-08 12:58:52
# 2                   15296          NaN  2018-02-08 13:49:41
# 3                   15300          NaN  2018-02-08 14:08:36
# 4                   19814          3.0  2018-02-09 14:01:05
# ...                   ...          ...                  ...
# 1508                16135          5.0  2020-04-25 13:22:38
# 1509                15891          NaN  2020-05-02 14:53:40
# 1510                15887          NaN  2020-05-02 15:00:54
# 1511              13127-1          NaN  2020-06-09 15:42:04
# 1512                16230          NaN  2020-07-20 11:00:00
#
#                                              post_title  \
# 0                                     Bon cadeau de 25€
# 1           Pierre Jean Villa Saint-Joseph Préface 2018
# 2       Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# ...

# %%
# Suppréssion des doublons

data_web  = data_web.drop_duplicates(subset=['id_web'])
data_web
# Out:
#                   id_web  total_sales            post_date  \
# 0    bon-cadeau-25-euros         10.0  2018-06-01 13:53:46
# 1                  15298          6.0  2018-02-08 12:58:52
# 2                  15296          NaN  2018-02-08 13:49:41
# 3                  15300          NaN  2018-02-08 14:08:36
# 4                  19814          3.0  2018-02-09 14:01:05
# ..                   ...          ...                  ...
# 762                16135          5.0  2020-04-25 13:22:38
# 767                15891          NaN  2020-05-02 14:53:40
# 768                15887          NaN  2020-05-02 15:00:54
# 797              13127-1          NaN  2020-06-09 15:42:04
# 798                16230          NaN  2020-07-20 11:00:00
#
#                                             post_title  \
# 0                                    Bon cadeau de 25€
# 1          Pierre Jean Villa Saint-Joseph Préface 2018
# 2      Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# ...

# %%
# Vérification des erreurs lexical

data_web[data_web['id_web']=='13127-1']
# Out:
#       id_web  total_sales            post_date  \
# 797  13127-1          NaN  2020-06-09 15:42:04
#
#                                        post_title  \
# 797  Clos du Mont-Olivet Châteauneuf-du-Pape 2007
#
#                                           post_excerpt  \
# 797  Nez gracieux, très élégant avec une touche flo...
#
#                                           post_name post_type
# 797  clos-du-mont-olivet-chateauneuf-du-pape-2007-2   product

# %%
# Vérification des erreurs lexical

data_web[data_web['id_web']=='13127']
# Out:
#    id_web  total_sales            post_date  \
# 18  13127         23.0  2018-02-12 11:18:33
#
#                                       post_title  \
# 18  Clos du Mont-Olivet Châteauneuf-du-Pape 2012
#
#                                          post_excerpt  \
# 18  Nez gracieux, très élégant avec une touche flo...
#
#                                        post_name post_type
# 18  clos-du-mont-olivet-chateauneuf-du-pape-2012   product

# %%
# Remplacer les valeur nulles (Nan) de la colonne ‘total_sales’ par des zéro

data_web = data_web.replace(np.nan, 0)
data_web.sort_values(by=['id_web'], ascending=False)
# Out:
#                   id_web  total_sales            post_date  \
# 0    bon-cadeau-25-euros         10.0  2018-06-01 13:53:46
# 422                 9937          4.0  2018-05-17 12:55:13
# 215                 9636          0.0  2018-03-22 10:44:57
# 206                 9562          0.0  2018-03-02 10:57:02
# 531                 8463          0.0  2018-11-26 11:25:35
# ..                   ...          ...                  ...
# 257                11049          0.0  2018-04-13 16:07:49
# 281                10814          0.0  2018-04-17 10:12:40
# 321                10775          0.0  2018-04-17 21:28:52
# 255                10459          0.0  2018-04-13 15:58:19
# 628                10014          0.0  2019-04-04 15:45:23
#
#                                             post_title  \
# 0                                    Bon cadeau de 25€
# 422  Marcel Richaud Cairanne Rouge Les Estrambords ...
# 215  Wemyss Malts Blended Malt Scotch Whisky The Hi...
# ...

# %%
#premiere vu des données ERP
# Aucune valeur nulles (NaN)
#Pas d'erreur lexical

data_erp =pd.read_csv('erp.csv')
data_erp.info()
data_erp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    float64
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 32.4+ KB
#    product_id  onsale_web  price  stock_quantity stock_status
# 0        3847           1   24.2               0   outofstock
# 1        3849           1   34.3               0   outofstock
# 2        3850           1   20.8               0   outofstock
# 3        4032           1   14.1               0   outofstock
# 4        4039           1   46.0               0   outofstock

# %%
#Vérification des valeurs nulles
# pas de valeurs nulles

print(data_erp.isnull().sum())
# Out:
# product_id        0
# onsale_web        0
# price             0
# stock_quantity    0
# stock_status      0
# dtype: int64

# %%
# Vérification des doublons
# Pas de doublons

data_erp.loc[data_erp['product_id'].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [product_id, onsale_web, price, stock_quantity, stock_status]
# Index: []

# %%
# Recherche des erreurs de saisie
# Filtre les produits qui sont marqués comme étant en stock ('instock').
# Identifie les erreurs parmi ces produits, c'est-à-dire ceux qui ont une quantité en stock de 0.
# Le DataFrame errorinstock contient donc les produits qui sont incorrectement marqués comme étant en stock, mais qui ont en fait une quantité de stock de 0.

instock = data_erp[data_erp['stock_status']== 'instock']
errorinstock = instock[instock['stock_quantity'] ==0] 

errorinstock
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status
# 443        4954           1   25.0               0      instock

# %%
# Recherche des erreurs de saisie

outofstock = data_erp[data_erp['stock_status']== 'outofstock']
erroroutofstock = outofstock[outofstock['stock_quantity'] !=0] 

erroroutofstock
# Out:
# Empty DataFrame
# Columns: [product_id, onsale_web, price, stock_quantity, stock_status]
# Index: []

# %%
#  Correction des stocks
data_erp['stock_status'] = np.where(data_erp['stock_quantity']==0, 'outofstock', 'instock')

# %%
# Vérification si la correction des erreurs à fonctionner

instock = data_erp[data_erp['stock_status']== 'instock']
errorinstock = instock[instock['stock_quantity'] ==0] 

errorinstock
# Out:
# Empty DataFrame
# Columns: [product_id, onsale_web, price, stock_quantity, stock_status]
# Index: []

# %%
#Nettoyage des données
#  Aucune valeur nulles (NaN) dans la colonne ‘product_id’
# Des valeurs nulles (NaN) dans la colonne ‘id_web’

data_liaison =pd.read_csv('liaison.csv')
data_liaison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  825 non-null    int64
#  1   id_web      734 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 13.0+ KB

# %%
# recherche de valeurs nulles
# 91 valeurs nulles dans id_web

print(data_liaison.isnull().sum())
# Out:
# product_id     0
# id_web        91
# dtype: int64

# %%
# Suppression des valeurs nulles 

data_liaison = data_liaison.dropna()
#print(data_liaison.isnull().sum())
# Out:
# product_id    0
# id_web        0
# dtype: int64

# %%
#Recherche des doublons
#Pas de doublons

data_liaison.loc[data_liaison['id_web'].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [product_id, id_web]
# Index: []

# %%
#Premier merge entre les données de liaison et les données ERP

dataLE = pd.merge(data_liaison, data_erp, how='inner', on=['product_id'])
dataLE
# Out:
#      product_id   id_web  onsale_web  price  stock_quantity stock_status
# 0          3847    15298           1   24.2               0   outofstock
# 1          3849    15296           1   34.3               0   outofstock
# 2          3850    15300           1   20.8               0   outofstock
# 3          4032    19814           1   14.1               0   outofstock
# 4          4039    19815           1   46.0               0   outofstock
# ..          ...      ...         ...    ...             ...          ...
# 729        7023    15891           1   27.5              15      instock
# 730        7025    15887           1   69.0               2      instock
# 731        7247  13127-1           1   54.8              23      instock
# 732        7329  14680-1           0   26.5              14      instock
# 733        7338    16230           1   16.3              45      instock
#
# [734 rows x 6 columns]

# %%
#Deuxième merge entre le premier merge et les données WEB

data = pd.merge(dataLE, data_web, how='inner', on=['id_web'])
data
# Out:
#      product_id   id_web  onsale_web  price  stock_quantity stock_status  \
# 0          3847    15298           1   24.2               0   outofstock
# 1          3849    15296           1   34.3               0   outofstock
# 2          3850    15300           1   20.8               0   outofstock
# 3          4032    19814           1   14.1               0   outofstock
# 4          4039    19815           1   46.0               0   outofstock
# ..          ...      ...         ...    ...             ...          ...
# 709        6930    16135           1    8.4              83      instock
# 710        7023    15891           1   27.5              15      instock
# 711        7025    15887           1   69.0               2      instock
# 712        7247  13127-1           1   54.8              23      instock
# 713        7338    16230           1   16.3              45      instock
#
#      total_sales            post_date  \
# 0            6.0  2018-02-08 12:58:52
# ...

# %%
#Calcul du CA par produit et du CA total
#Ajout d’une colonne ‘CA’ qui présente le chiffre d’affaire de chaque produits

data = data.assign(CA = data['price']*data['total_sales']) 
data[['product_id', 'id_web', 'price', 'total_sales', 'post_title', 'CA']]
# Out:
#      product_id   id_web  price  total_sales  \
# 0          3847    15298   24.2          6.0
# 1          3849    15296   34.3          0.0
# 2          3850    15300   20.8          0.0
# 3          4032    19814   14.1          3.0
# 4          4039    19815   46.0          0.0
# ..          ...      ...    ...          ...
# 709        6930    16135    8.4          5.0
# 710        7023    15891   27.5          0.0
# 711        7025    15887   69.0          0.0
# 712        7247  13127-1   54.8          0.0
# 713        7338    16230   16.3          0.0
#
#                                             post_title     CA
# 0          Pierre Jean Villa Saint-Joseph Préface 2018  145.2
# 1      Pierre Jean Villa Saint-Joseph Rouge Tildé 2017    0.0
# 2    Pierre Jean Villa Crozes-Hermitage Accroche Co...    0.0
# 3    Pierre Jean Villa IGP Collines Rhodaniennes Ga...   42.3
# 4            Pierre Jean Villa Côte Rôtie Carmina 2017    0.0
# ...

# %%
# Calcul du du CA total
print(data['CA'].sum())
# Out:
# 70568.6

# %%
# Analyse des prix des produits
#  créer un boxplot

# import matplotlib.pyplot as plt
# import seaborn as sns

# plt.figure(figsize=(10, 6))
# sns.boxplot(x='product_id', y='CA', data=data)

# # Ajouter un titre et des labels aux axes
# plt.title('Boxplot du chiffre d\'affaires par product_id')
# plt.xlabel('Product ID')
# plt.ylabel('Chiffre d\'Affaires (CA)')

# # Afficher le graphique
# plt.show()

# %%
#df = pd.DataFrame(data, columns=list('price'))
#ax = df.plot.box(column="price")

boxplot = data.boxplot(column=['price'])
boxplot.plot()
# plt.xlabel('prix')
# plt.ylabel('Price')

plt.show()

# %%
# Calcul de la moyenne
# Calcul de la mediane

print( "La moyenne est : ",data['price'].mean().round(2))
print("La médiane est : ", data['price'].median())

# Calculer Q1 (25e percentile)
Q1 = data['price'].quantile(0.25).round()

# Calculer Q3 (75e percentile)
Q3 = data['price'].quantile(0.75).round()

# Calculer IQR (Intervalle Interquartile)
IQR = (Q3 - Q1).round()

# Afficher les résultats
print("Q1 :", Q1)
print("Q3 :", Q3)
print("IQR  :", IQR)

#minimun et maximum
print("min : ", data['price'].min())
print("max : ", data['price'].max())
# Out:
# La moyenne est :  32.49
# La médiane est :  23.55
# Q1 (25e percentile) : 14.0
# Q3 (75e percentile) : 42.0
# IQR (Intervalle Interquartile) : 28.0
# min :  5.2
# max :  225.0

# %%
#Top 5 des produits les plus vendu

data_sorted = data.sort_values(by='total_sales', ascending=False)
print(data_sorted)
# Out:
#      product_id id_web  onsale_web  price  stock_quantity stock_status  \
# 194        4334   7818           1   49.0               0   outofstock
# 71         4144   1662           1   49.0              11      instock
# 30         4068  16416           1   16.6             157      instock
# 119        4200  16295           1    5.8             190      instock
# 97         4172  16210           1    5.7             167      instock
# ..          ...    ...         ...    ...             ...          ...
# 352        4791  14599           1   13.6              24      instock
# 351        4790  15732           1   11.1              43      instock
# 348        4786  15881           1   12.1              37      instock
# 346        4784  15734           1   28.5              10      instock
# 713        7338  16230           1   16.3              45      instock
#
#      total_sales            post_date  \
# 194         96.0  2018-03-01 14:02:44
# ...

# %%
data_sorted = data.sort_values(by='CA', ascending=False)
print(data_sorted)
